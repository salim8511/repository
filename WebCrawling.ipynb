# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %%
feature_list = ['제목','사기유형','발생지역','발생시기','피해금액', 'URL']
def soup_contents(start_article, num_articles):
    fraud = pd.DataFrame(np.zeros(shape=(num_articles, len(feature_list))), columns = feature_list)
    for i in range(num_articles):
        base_url ='http://news.kotra.or.kr/user/globalBbs/kotranews/27/globalBbsDataView.do?setIdx=256&dataIdx={}'
        url = base_url.format(start_article+i)
        html = get_html(url)
        soup = BeautifulSoup(html, 'html.parser')
        title = soup.find('title').text
        all_font_tags = soup.find_all("font")
        list_of_inner_text = [x.text for x in all_font_tags]
        if len(list_of_inner_text) > 4: #게시물 번호가 이어지지 않는 경우, 에러를 방지하기 위해서 list 값의 개수 체크
            fraud.loc[i, '제목'] = title
            fraud.loc[i, '사기유형'] = list_of_inner_text[1]
            fraud.loc[i, '발생지역'] = list_of_inner_text[2]
            fraud.loc[i, '발생시기'] = list_of_inner_text[3]
            fraud.loc[i, '피해금액'] = list_of_inner_text[4]
            fraud.loc[i, 'URL'] = url
    return fraud

# %%
fraud_fin = soup_contents(146346,124)

# %%
fraud_fin.to_csv('fraud_fin.csv')

# %%
fraud_fin
# Out:
#                                                     제목  \
# 0    지급보증 ‘계약’ 체결해야 대금 징수 가능-무역사기사례-비즈니스 정보-kotra 해...
# 1           파산 바이어 결제 미 이행-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 2    수준 미달 콘텐츠 납품 뒤 재작업 거부-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 3        마스터 L/C 취소에 따른 분쟁-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 4            운송 중 도난당해 클레임-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 5          가짜 계좌를 보내 대금 사취-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 6         미 지급 대금 분할 지급 요청-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 7       거래 종결 후에도 수수료 미 지급-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 8    가짜 계좌로 송금을 요청하는 위조 공문서-무역사기사례-비즈니스 정보-kotra 해외...
# 9            수산물업체 사칭한 사기범-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 10   가짜 이메일 주소로 보낸 위조 인보이스-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 11       가짜 연락처로 구매 수수료 요구-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 12        물품 하자 핑계로 잔금 미지급-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 13        이메일 해킹으로 수취은행 변경-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 14       해킹으로 연락처와 송금은행 변경-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 15            선적 후 중도금 미지급-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 16      불량 물품 납품 후 손해배상 거부-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 17            해커가 한국 벤더 사칭-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 18   이메일 전화번호 해킹으로 결제대금 사취-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 19         선금 수령 후 납품 미 이행-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 20             해킹으로 계약서 위조-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 21        중개수수료 받지 못한 에이전트-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 22      국내 기업 사칭해 결제 정보 변경-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 23         바이어의 상습적인 결제 지연-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 24      해외 송금 담당자 사칭 송금 요구-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 25     현지 송금 방식 미숙지로 본 피해 -무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 26   결제은행 변경이란 가짜 이메일 받고 송금 -무역사기사례-비즈니스 정보-kotra 해...
# 27    D/A외상 거래 통보하며 대금 미지급-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 28       타국 은행으로 송금 요청한 해커-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 29       은행을 변경해 본 회사를 노린다-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# ..                                                 ...
# 94      이메일 주소와 P/I 위조한 해커-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 95      다른 업체 계좌로 송금돼 소송 중-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 96           은행의 신용장 거래 사기-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 97        허술한 계정 관리는 해커의 밥-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 98           원부자재 공급 사기 시도-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 99          건설 프로젝트 브로커 사기-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 100    준설 프로젝트 개발권, 주문서 위조-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 101     무역관의 신용도 전달로 거래 성사-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 102          폐기물 수출 허위 브로커-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 103                                                  0
# 104      대금 지불 후 오더 제품 미수령-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 105     업체는 독일, 은행 계좌는 동유럽-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 106  중국에서 작가의 저작권을 어떻게 보호해야 하나?-무역사기사례-비즈니스 정보-kotr...
# 107        현지 에이전트가 선수금 요구-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 108        실존 회사 사업자등록증 위조-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 109               유령기업의 사기-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 110       위조 서류로 투자 컨설팅 사기-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 111               유령기업 판매자-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 112      전시회 비지정 업체의 무역 사기-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 113           현지 담당 직원의 착복-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 114     유사한 업체 이름 및 사이트 도용-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 115                유령업체 사기-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 116              공증비 착복 기도-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 117               물품 견본 사취-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 118           대량 구매 건으로 유혹-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 119      저금리 대출 미끼로 선수금 요청-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 120          위조 서류를 이용한 사기-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 121             현지 위조지폐 사기-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 122        국내 기업이 A/S 미 이행-무역사기사례-비즈니스 정보-kotra 해외시장뉴스
# 123  위안화 국제결제시스템 출범, 외국계 은행 및 기업이 최대 수혜자 -무역사기사례-비즈...
#
#                                      사기유형  \
# 0                         □ 사기유형: 결제 미이행
# 1                         □ 사기유형: 결제 미이행
# 2                         □ 사기유형: 결제 미이행
# 3                         □ 사기유형: 결제 미이행
# 4                         □ 사기유형: 결제 미이행
# 5                         □ 사기유형: 이메일 해킹
# 6                         □ 사기유형: 결제 미이행
# 7                         □ 사기유형: 결제 미이행
# 8                          □ 사기유형: 이메일 해킹
# 9                         □ 사기유형: 결제 미이행
# 10                        □ 사기유형: 이메일 해킹
# 11                        □ 사기유형: 이메일 해킹
# 12                        □ 사기유형: 결제 미이행
# 13                        □ 사기유형: 이메일 해킹
# 14                               □ 사기유형:
# 15                        □ 사기유형: 결제 미이행
# 16                        □ 사기유형: 결제 미이행
# 17                        □ 사기유형: 이메일 해킹
# 18                        □ 사기유형: 이메일 해킹
# 19                        □ 사기유형: 결제 미이행
# 20                        □ 사기유형: 이메일 해킹
# 21                        □ 사기유형: 결제 미이행
# 22                        □ 사기유형: 이메일 해킹
# 23                        □ 사기유형: 결제 미이행
# 24                        □ 사기유형: 이메일 해킹
# 25                        □ 사기유형: 결제 미이행
# 26                        □ 사기유형: 이메일 해킹
# 27                        □ 사기유형: 결제 미이행
# 28                         □ 사기유형: 이메일 해킹
# 29                        □ 사기유형: 이메일 해킹
# ..                                    ...
# 94                        □ 사기유형: 이메일 해킹
# 95                        □ 사기유형: 이메일 해킹
# 96                             □ 사기유형: 기타
# 97                        □ 사기유형: 이메일 해킹
# 98                                □ 사기유형:
# 99                             □ 사기유형: 기타
# 100                            □ 사기유형: 기타
# 101                       □ 사기유형: 이메일 해킹
# 102                            □ 사기유형: 기타
# 103                                     0
# 104                            □ 사기유형: 기타
# 105                            □ 사기유형: 기타
# 106            중국에서 작가의 저작권을 어떻게 보호해야 하나?
# 107                           □ 사기유형: 기타
# 108                           □ 사기유형: 기타
# 109                            □ 사기유형: 기타
# 110                            □ 사기유형: 기타
# 111                           □ 사기유형: 기타
# 112                            □ 사기유형: 기타
# 113                           □ 사기유형: 기타
# 114                            □ 사기유형: 기타
# 115                            □ 사기유형: 기타
# 116                           □ 사기유형: 기타
# 117                            □ 사기유형: 기타
# 118                            □ 사기유형: 기타
# 119                            □ 사기유형: 기타
# 120                            □ 사기유형: 기타
# 121                            □ 사기유형: 기타
# 122                           □ 사기유형: 기타
# 123  위안화 국제결제시스템 출범, 외국계 은행 및 기업이 최대 수혜자
#
#                                       발생지역                             발생시기  \
# 0                       □ 발생지역: 모스크바(러시아)　               □ 발생시기: 2014년 10월
# 1                       □ 발생지역: 디트로이트(미국)　                   □ 발생시기: 2012년
# 2                        □ 발생지역: 토론토(캐나다)　              □ 발생시기: 2013~2014년
# 3                       □ 발생지역: 다카(방글라데시)　             □ 발생시기: 2014년 연중 3회
# 4                         □ 발생지역: 뉴델리(인도)　                □ 발생시기: 2014년 5월
# 5                         □ 발생지역: 킨샤사(콩고)　                □ 발생시기: 2015년 3월
# 6                   □ 발생지역: 아디스아바바(에티오피아)　                □ 발생시기: 2015년 5월
# 7                     □ 발생지역: 부쿠레슈티(루마니아)　                □ 발생시기: 2014년 8월
# 8                       □ 발생지역: 모스크바(러시아)　                □ 발생시기: 2015년 1월
# 9                      □ 발생지역: 스톡홀름(노르웨이)　               □ 발생시기: 2014년 11월
# 10                   □ 발생지역: 상트페테르부르크(러시아)               □ 발생시기: 2014년 10월
# 11                     □ 발생지역: 키예프(우크라이나)　                □ 발생시기: 2013년 6월
# 12                        □ 발생지역: 파리(프랑스)　                □ 발생시기: 2013년 6월
# 13                      □ 발생지역: 비엔티안(라오스)　                □ 발생시기: 2015년 3월
# 14                                                                  이메일 해킹
# 15                        □ 발생지역: 쑤저우(중국)　                □ 발생시기: 2012년 6월
# 16                        □ 발생지역: 쑤저우(중국)　                   □ 발생시기: 2013년
# 17                         □ 발생지역: 양곤(미얀마)                □ 발생시기: 2015년 1월
# 18                       □ 발생지역: 하노이(베트남)　                □ 발생시기: 2015년 3월
# 19                         □ 발생지역: 단둥(중국)　                □ 발생시기: 2014년 2월
# 20                       □ 발생지역: 하노이(베트남)　                □ 발생시기: 2013년 8월
# 21                             □ 발생지역: 한국　                □ 발생시기: 2013년 8월
# 22                       □ 발생지역: 호찌민(베트남)　               □ 발생시기: 2014년 11월
# 23                     □ 발생지역: 멕시코시티(멕시코)　                □ 발생시기: 2014년 2월
# 24                           □ 발생지역: 싱가포르　                □ 발생시기: 2014년 2월
# 25                     □ 발생지역: 카사블랑카(모로코)　                □ 발생시기: 2012년 4월
# 26                    □ 발생지역: 수라바야(인도네시아)　                □ 발생시기: 2015년 3월
# 27                        □ 발생지역: 알제(알제리)　                 □ 발생시기: 2014년 말
# 28                          □ 발생지역: 방콕(태국)               □ 발생시기: 2013년 11월
# 29                     □ 발생지역: 로스앤젤레스(미국)　    □ 발생시기: 2013년 11월 ~ 2014년 2월
# ..                                     ...                              ...
# 94                       □ 발생지역: 무스카트(오만)　               □ 발생시기: 2014년 10월
# 95                     □ 발생지역: 텔아비브(이스라엘)　                □ 발생시기: 2014년 5월
# 96                      □ 발생지역: 바쿠(아제르바이잔)               □ 발생시기: 2014년 10월
# 97                       □ 발생지역: 카이로(이집트)　               □ 발생시기: 2015년 12월
# 98                                                                      기타
# 99                   □ 발생지역: 쿠알라룸푸르(말레이시아)                    □ 발생시기: 2012년
# 100                  □ 발생지역: 쿠알라룸푸르(말레이시아)                    □ 발생시기: 2012년
# 101                          □ 발생지역: 쿠웨이트　               □ 발생시기: 2014년 11월
# 102                  □ 발생지역: 쿠알라룸푸르(말레이시아)                    □ 발생시기: 2014년
# 103                                      0                                0
# 104                    □ 발생지역: 부쿠레슈티(루마니아)                □ 발생시기: 2015년 3월
# 105                       □ 발생지역: 함부르크(독일)                 □ 발생시기: 2014년 7월
# 106          - 중국, 작가의 저작권 침해 계속 일어나고 있어 -              - 작가권리 보호방법 마련 시급 -
# 107                       □ 발생지역: 함부르크(독일)                □ 발생시기: 2014년 7월
# 108                       □ 발생지역: 브뤼셀(벨기에)                 □ 발생시기: 2013년 2월
# 109                         □ 발생지역: 런던(영국)                □ 발생시기: 2014년 1월
# 110                      □ 발생지역: 밀라노(이탈리아)               □ 발생시기: 2014년 10월
# 111                     □ 발생지역: 부다페스트(헝가리)                □ 발생시기: 2014년 3월
# 112                        □ 발생지역: 광저우(중국)                □ 발생시기: 2014년 10월
# 113                       □ 발생지역: 타이베이(대만)                □ 발생시기: 2014년 4월
# 114                         □ 발생지역: 샤먼(중국)                □ 발생시기: 2014년 8월
# 115                         □ 발생지역: 샤먼(중국)               □ 발생시기: 2013년 11월
# 116                        □ 발생지역: 정저우(중국)                □ 발생시기: 2015년 1월
# 117                        □ 발생지역: 정저우(중국)                □ 발생시기: 2015년 1월
# 118                     □ 발생지역: 멕시코시티(멕시코)                □ 발생시기: 2013년 4월
# 119                    □ 발생지역: 두바이(아랍에미리트)                □ 발생시기: 2014년 6월
# 120                   □ 발생지역: 두바이(아랍에미리트)　                □ 발생시기: 2014년 5월
# 121                           □ 발생지역: 쿠웨이트                □ 발생시기: 2014년 7월
# 122                      □ 발생지역: 카라치(파키스탄)                    □ 발생시기: 2013년
# 123  - 스탠다드차타드, 출범 당일 오전에만 200여 건의 업무 진행 -  - 시스템 출시로 한 발 더 편리해진 원-위안화 거래 -
#
#                                                 피해금액  \
# 0                              □ 피해금액: 2,000,000 USD
# 1                 □ 피해금액: 약 20,000,000원 / 20,000 USD
# 2                 □ 피해금액: 약 66,000,000원 / 66,000 CAD
# 3                              □ 피해금액: 약 100,000 USD
# 4    □ 피해금액: 70,000 USD (원고는 7,000 USD로 되어 있음-확인 요망)
# 5                                 □ 피해금액: 19,000 USD
# 6                                □ 피해금액: 800,000 USD
# 7                                 □ 피해금액: 14,000 EUR
# 8                                         □ 피해금액: 없음
# 9                   □ 피해금액: 50,000,000원 / 45,000 USD
# 10                                □ 피해금액: 5,000 USD
# 11                                        □ 피해금액: 없음
# 12                                □ 피해금액: 20,000 USD
# 13                                        □ 피해금액: 없음
# 14                            □ 발생지역: 쿠알라룸푸르(말레이시아)
# 15                       □ 피해금액: 200,000~300,000 USD
# 16                             □ 피해금액: 400,000,000 원
# 17                                □ 피해금액: 50,000 USD
# 18                              □ 피해금액: 약 40,000 USD
# 19                                □ 피해금액: 42,161 USD
# 20                                 □ 피해금액: 8,325 USD
# 21                 □ 피해금액: 22,130,000 원 / 20,000 USD
# 22                                 □ 피해금액: 8,000 USD
# 23                   □ 피해금액: 4,500,000 원 / 4,328 USD
# 24                                        □ 피해금액: 없음
# 25                                 □ 피해금액: 4,750 USD
# 26                                □ 피해금액: 60,000 USD
# 27                                □ 피해금액: 50,000 USD
# 28                                        □ 피해금액: 없음
# 29                   □ 피해금액: 80,000,000원(70,000 USD)
# ..                                               ...
# 94                                □ 피해금액: 24,282 USD
# 95                                □ 피해금액: 30,000 USD
# 96                                        □ 피해금액: 없음
# 97                                □ 피해금액: 35,000 USD
# 98                                □ 발생지역: 키예프(우크라이나)
# 99                                        □ 피해금액: 없음
# 100                                       □ 피해금액: 없음
# 101                                       □ 피해금액: 없음
# 102                                       □ 피해금액: 없음
# 103                                                0
# 104                                □ 피해금액: 1,694 USD
# 105                               □ 피해금액: 60,000 USD
# 106
# 107                               □ 피해금액: 10,000 USD
# 108                                      □ 피해금액: 미확인
# 109                                      □ 피해금액: 미확인
# 110                                       □ 피해금액: 없음
# 111                                       □ 피해금액: 없음
# 112                              □ 피해금액: 40,000 RMB
# 113                                    □ 피해금액: 확인 불가
# 114                                       □ 피해금액: 없음
# 115                                    □ 피해금액: 확인 불가
# 116                                       □ 피해금액: 없음
# 117                                      □ 피해금액: 미확인
# 118                                       □ 피해금액: 없음
# 119                                       □ 피해금액: 없음
# 120                                       □ 피해금액: 없음
# 121                               □ 피해금액: 22,249 USD
# 122                □ 피해금액: 270,000,000원/ 270,000 USD
# 123
#
#                                                    URL
# 0    http://news.kotra.or.kr/user/globalBbs/kotrane...
# 1    http://news.kotra.or.kr/user/globalBbs/kotrane...
# 2    http://news.kotra.or.kr/user/globalBbs/kotrane...
# 3    http://news.kotra.or.kr/user/globalBbs/kotrane...
# 4    http://news.kotra.or.kr/user/globalBbs/kotrane...
# 5    http://news.kotra.or.kr/user/globalBbs/kotrane...
# 6    http://news.kotra.or.kr/user/globalBbs/kotrane...
# 7    http://news.kotra.or.kr/user/globalBbs/kotrane...
# 8    http://news.kotra.or.kr/user/globalBbs/kotrane...
# 9    http://news.kotra.or.kr/user/globalBbs/kotrane...
# 10   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 11   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 12   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 13   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 14   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 15   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 16   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 17   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 18   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 19   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 20   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 21   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 22   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 23   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 24   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 25   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 26   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 27   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 28   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 29   http://news.kotra.or.kr/user/globalBbs/kotrane...
# ..                                                 ...
# 94   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 95   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 96   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 97   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 98   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 99   http://news.kotra.or.kr/user/globalBbs/kotrane...
# 100  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 101  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 102  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 103                                                  0
# 104  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 105  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 106  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 107  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 108  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 109  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 110  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 111  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 112  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 113  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 114  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 115  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 116  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 117  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 118  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 119  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 120  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 121  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 122  http://news.kotra.or.kr/user/globalBbs/kotrane...
# 123  http://news.kotra.or.kr/user/globalBbs/kotrane...
#
# [124 rows x 6 columns]
